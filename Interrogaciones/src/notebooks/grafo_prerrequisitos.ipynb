# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import os
from bokeh.io import output_notebook, show, save
# %matplotlib inline

# %%
output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1001">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.io import output_notebook, show, save
from bokeh.models import Range1d, Circle, ColumnDataSource, MultiLine, EdgesAndLinkedNodes, NodesAndLinkedEdges, LabelSet
from bokeh.plotting import figure
from bokeh.plotting import from_networkx
from bokeh.palettes import Blues8, Reds8, Purples8, Oranges8, Viridis8, Spectral8
from bokeh.transform import linear_cmap
from networkx.algorithms import community

# %%
from grafos.drawing import dibujar_grafo
from grafos.prerrequisito import anadir_arcos_transitividad

# %%
from filtracion_archivos.prerrequisitos import cursos_ingenieria, diccionario_cursos_y_prerrequisitos

# %%
path_excel = os.path.join("excel_horarios", "Listado_materias.xlsx")
dataframe_ing = cursos_ingenieria(path_excel)
cursos = diccionario_cursos_y_prerrequisitos(dataframe_ing)
# Out:
# C:\Users\franc\Desktop\Universidad\5TO SEMESTRE\ICS2985_iPre\src\filtracion_archivos\prerrequisitos.py:30: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataframe_ing["Prerrequisitos"] = dataframe_ing["Prerrequisitos"].str.replace(
# C:\Users\franc\Desktop\Universidad\5TO SEMESTRE\ICS2985_iPre\src\filtracion_archivos\prerrequisitos.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_ing["Prerrequisitos"] = dataframe_ing["Prerrequisitos"].str.replace(
# C:\Users\franc\Desktop\Universidad\5TO SEMESTRE\ICS2985_iPre\src\filtracion_archivos\prerrequisitos.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# print(cursos)
graph = nx.from_dict_of_lists(cursos, create_using = nx.DiGraph)

# %%
graph = graph.reverse()
print("El grafo actualmente es ", graph)
# Out:
# El grafo actualmente es  DiGraph with 1218 nodes and 822 edges

# %%
dibujar_grafo("Grafo de ramos y prerrequisitos", graph)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 dibujar_grafo("Grafo de ramos y prerrequisitos", graph)
#
# File ~\Desktop\Universidad\5TO SEMESTRE\ICS2985_iPre\src\grafos\drawing.py:57, in dibujar_grafo(title, grafo)
#      55 plot.height = 900
#      56 # network_graph = from_networkx(grafo, nx.nx_agraph.graphviz_layout(grafo), scale=10, center=(0, 0))
# ---> 57 network_graph = from_networkx(grafo, nx.spring_layout(grafo), scale=10, center=(0, 0))
#      59 # Set node sizes and colors according to node degree (color as category from attribute)
#      61 minimum_value_color = min(
#      62     network_graph.node_renderer.data_source.data[color_by_this_attribute])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\bokeh\plotting\graph.py:123, in from_networkx(graph, layout_function, **kwargs)
# ...

# %%
lista_nodos = [x for x in graph.nodes]
H = nx.subgraph(graph, ['IMM2012', "IMM3310", "IMM3360"], )
nx.draw(H, with_labels=True, font_weight='bold', node_color='lightblue', node_size=500)

# %%
print(list(nx.neighbors(graph, "IMM2053")))
# Out:
# ['IMM3005', 'IMM3023', 'IMM3033', 'IMM3053', 'IMM3212', 'IMM3255', 'IMM3521']

# %%
for i in list(graph.in_edges):
    if "IMM3212" in i:
        print(i)
# Out:
# ('ICH1104', 'IMM3212')
# ('IMM2053', 'IMM3212')

# %%
anadir_arcos_transitividad(graph)

# %%
H = nx.subgraph(graph, ['IMM2012', "IMM3310", "IMM3360"], )
nx.draw(H, with_labels=True, font_weight='bold', node_color='lightblue', node_size=500)

# %%
dibujar_grafo("Grafo prerrequisitos con arcos de transitividad", graph)
# Out:
#   <div class="bk-root" id="ff6a112c-7c6b-4745-8dcb-693f50c3288c" data-root-id="3244"></div>

# %%
print("El grafo es: ", graph)
# Out:
# El grafo es:  DiGraph with 1218 nodes and 1129 edges
